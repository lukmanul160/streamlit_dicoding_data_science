# %% [markdown]
# # Proyek Analisis Data: Bike Sharing Dataset
#
#
# ---
#
#
# Nama : Lukmanul Hakim
#
# Email : lukmanul160@gmail.com
#
# ID Dicoding :
#
# username : lukmanul160

# %% [markdown]
# # Menentukan Pertanyaan Bisnis
#
#
#
# ---
#
#
# 1.   Kapan waktu(jam) yang sering terjadi peminjaman/rent bike sharing yang ada
# 2.   Berapa banyak dalam satu hari/waktu(bisa harian/bulanan/tahunan) dilakuakn peminjaman rent bike sharing
# 3.   pengaruh cuaca(temp/atemp/hum/windspeed) terkait dengan banyaknya peminjam/rent yang terjadi

# %% [markdown]
# # Menyaipkan semua library yang dibuthkan

# %%
# import depedency/package
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.graphics.gofplots import qqplot

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ## Import Data

# %%
# import dataset
df_days = pd.read_csv('day.csv')
df_hours = pd.read_csv('hour.csv')

# %% [markdown]
# ### Assessing Data

# %%
# cek field/feature yang ada pada dataset day
df_days.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
# cek field/feature yang ada pada dataset hour
df_hours.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
# Analisis dekripsi data days
df_days.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
# Analisis dekripsi data days
df_hours.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %%
df_days.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
df_hours.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %% [markdown]
# Melakukan Pengecekan apakah ada data yang kosong

# %%
df_days.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df_hours.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# Melakukan pengecekan apakah ada data duplikasi

# %%
print("Jumlah duplikasi Days: ", df_days.duplicated().sum())
# Out:
# Jumlah duplikasi Days:  0

# %%
print("Jumlah duplikasi Hours: ", df_hours.duplicated().sum())
# Out:
# Jumlah duplikasi Hours:  0

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Lakukan perubahan terkait jenis data yang ada dan lakukan clean drop feature/field yang tidak dibutuhkan

# %%
# pada 2 dataset terdapat dtime dimana masih bernilai/jenis object
# df_days
df_days['dteday'] = pd.to_datetime(df_days['dteday'])
# df_hours
df_hours['dteday'] = pd.to_datetime(df_hours['dteday'])

# %%
df_days.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB

# %%
df_hours.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  datetime64[ns]
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(12)
# memory usage: 2.3 MB

# %%
# lakukan perubahan terkait dengan nama field/feature yang ada dimana hal tersebut kurang informatif
# df_hours
df_hours = df_hours.rename(columns={'weathersit':'weather',
                       'yr':'year',
                       'mnth':'month',
                       'hr':'hour',
                       'hum':'humidity',
                       'cnt':'count'})

# %%
# ubah data dimana data kategorikal
cols = ['season' , 'month' , 'hour' , 'holiday' , 'weekday' , 'workingday' , 'weather']
for col in cols:
    df_hours[col] = df_hours[col].astype('category')

# %%
df_hours.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  datetime64[ns]
#  2   season      17379 non-null  category
#  3   year        17379 non-null  int64
#  4   month       17379 non-null  category
#  5   hour        17379 non-null  category
#  6   holiday     17379 non-null  category
#  7   weekday     17379 non-null  category
#  8   workingday  17379 non-null  category
#  9   weather     17379 non-null  category
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  humidity    17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  count       17379 non-null  int64
# dtypes: category(7), datetime64[ns](1), float64(4), int64(5)
# ...

# %%
# df_days
df_days = df_days.rename(columns={'weathersit':'weather',
                       'yr':'year',
                       'mnth':'month',
                       'hr':'hour',
                       'hum':'humidity',
                       'cnt':'count'})

# %%
# ubah data dimana data kategorikal
cols = ['season' , 'month'  , 'holiday' , 'weekday' , 'workingday' , 'weather']
for col in cols:
    df_days[col] = df_days[col].astype('category')

# %%
df_days.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    category
#  3   year        731 non-null    int64
#  4   month       731 non-null    category
#  5   holiday     731 non-null    category
#  6   weekday     731 non-null    category
#  7   workingday  731 non-null    category
#  8   weather     731 non-null    category
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  humidity    731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  count       731 non-null    int64
# dtypes: category(6), datetime64[ns](1), float64(4), int64(5)
# memory usage: 62.8 KB

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS(EDA)

# %%
df_days.head()
# Out:
#    instant     dteday season  year month holiday weekday workingday weather  \
# 0        1 2011-01-01      1     0     1       0       6          0       2
# 1        2 2011-01-02      1     0     1       0       0          0       2
# 2        3 2011-01-03      1     0     1       0       1          1       1
# 3        4 2011-01-04      1     0     1       0       2          1       1
# 4        5 2011-01-05      1     0     1       0       3          1       1
#
#        temp     atemp  humidity  windspeed  casual  registered  count
# 0  0.344167  0.363625  0.805833   0.160446     331         654    985
# 1  0.363478  0.353739  0.696087   0.248539     131         670    801
# 2  0.196364  0.189405  0.437273   0.248309     120        1229   1349
# 3  0.200000  0.212122  0.590435   0.160296     108        1454   1562
# 4  0.226957  0.229270  0.436957   0.186900      82        1518   1600

# %% [markdown]
# ## EDA DF DAYS

# %%
df_days.hist()
# Out:
# array([[<Axes: title={'center': 'instant'}>,
#         <Axes: title={'center': 'dteday'}>,
#         <Axes: title={'center': 'year'}>],
#        [<Axes: title={'center': 'temp'}>,
#         <Axes: title={'center': 'atemp'}>,
#         <Axes: title={'center': 'humidity'}>],
#        [<Axes: title={'center': 'windspeed'}>,
#         <Axes: title={'center': 'casual'}>,
#         <Axes: title={'center': 'registered'}>],
#        [<Axes: title={'center': 'count'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
df_days.corr()
# Out:
# <ipython-input-26-9dc612f19fdb>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_days.corr()
#              instant      year      temp     atemp  humidity  windspeed  \
# instant     1.000000  0.866025  0.150580  0.152638  0.016375  -0.112620
# year        0.866025  1.000000  0.047604  0.046106 -0.110651  -0.011817
# temp        0.150580  0.047604  1.000000  0.991702  0.126963  -0.157944
# atemp       0.152638  0.046106  0.991702  1.000000  0.139988  -0.183643
# humidity    0.016375 -0.110651  0.126963  0.139988  1.000000  -0.248489
# windspeed  -0.112620 -0.011817 -0.157944 -0.183643 -0.248489   1.000000
# casual      0.275255  0.248546  0.543285  0.543864 -0.077008  -0.167613
# registered  0.659623  0.594248  0.540012  0.544192 -0.091089  -0.217449
# ...

# %%
corr = df_days.corr()
plt.figure(figsize=(15,7))
sns.heatmap(corr, annot=True, annot_kws={'size':10})
# Out:
# <ipython-input-27-d7c0aba7e921>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df_days.corr()
# <Axes: >

# %%
df_days.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    category
#  3   year        731 non-null    int64
#  4   month       731 non-null    category
#  5   holiday     731 non-null    category
#  6   weekday     731 non-null    category
#  7   workingday  731 non-null    category
#  8   weather     731 non-null    category
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  humidity    731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  count       731 non-null    int64
# dtypes: category(6), datetime64[ns](1), float64(4), int64(5)
# memory usage: 62.8 KB

# %%
# plotting berdasarkan waktu(hour)
fig, ax = plt.subplots(figsize=(20,5))
sns.pointplot(data=df_days, x='month', y='count', hue='weekday', ax=ax)
ax.set(title='Plot total Berdasarkan bulan dan hari kerja ')
# Out:
# [Text(0.5, 1.0, 'Plot total Berdasarkan bulan dan hari kerja ')]

# %%
fig, ax = plt.subplots(figsize=(20,5))
sns.pointplot(data=df_hours, x='month', y='casual', hue='weekday', ax=ax)
ax.set(title='Total peminjaman sepeda berdasarkan pengguna tidak terdaftar')
# Out:
# [Text(0.5, 1.0, 'Total peminjaman sepeda berdasarkan pengguna tidak terdaftar')]

# %%
fig, ax = plt.subplots(figsize=(20,5))
sns.pointplot(data=df_hours, x='month', y='registered', hue='weekday', ax=ax)
ax.set(title='Total peminjaman sepeda berdasarkan pengguna  terdaftar')
# Out:
# [Text(0.5, 1.0, 'Total peminjaman sepeda berdasarkan pengguna  terdaftar')]

# %%
fig, ax = plt.subplots(figsize=(20,5))
sns.barplot(data=df_days, x='month', y='count', ax=ax)
ax.set(title='Total peminjaman sepeda berdsarkan bulan')
# Out:
# [Text(0.5, 1.0, 'Total peminjaman sepeda berdsarkan bulan')]

# %%
fig, ax = plt.subplots(figsize=(20,5))
sns.barplot(data=df_days, x='weekday', y='count', ax=ax)
ax.set(title='Total peminjaman sepeda berdasarkan hari kerja')
# Out:
# [Text(0.5, 1.0, 'Total peminjaman sepeda berdasarkan hari kerja')]

# %%
fig, (ax1,ax2) = plt.subplots(ncols=2, figsize=(20,5))
sns.regplot(x=df_days['temp'], y=df_days['count'], ax=ax1 ,color='red')
ax1.set(title="Hubungan antara pengguna dengan suhu/temperatur")
sns.regplot(x=df_days['humidity'], y=df_days['count'], ax=ax2)
ax2.set(title="hubungan antara kemebapan dengan pengguna")
# Out:
# [Text(0.5, 1.0, 'hubungan antara kemebapan dengan pengguna')]

# %%
fig, (ax1,ax2) = plt.subplots(ncols=2, figsize=(20,5))
sns.distplot(df_days['count'], ax=ax1 , color ='red')
ax1.set(title='Distribution of the users')
qqplot(df_days['count'], ax=ax2, line='s')
ax2.set(title='Theoritical quantiles')
# Out:
# <ipython-input-35-1342a712a069>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_days['count'], ax=ax1 , color ='red')
# [Text(0.5, 1.0, 'Theoritical quantiles')]

# %% [markdown]
# ## EDA DF HOURS

# %%
df_hours.hist()
# Out:
# array([[<Axes: title={'center': 'instant'}>,
#         <Axes: title={'center': 'dteday'}>,
#         <Axes: title={'center': 'year'}>],
#        [<Axes: title={'center': 'temp'}>,
#         <Axes: title={'center': 'atemp'}>,
#         <Axes: title={'center': 'humidity'}>],
#        [<Axes: title={'center': 'windspeed'}>,
#         <Axes: title={'center': 'casual'}>,
#         <Axes: title={'center': 'registered'}>],
#        [<Axes: title={'center': 'count'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
df_hours.corr()
# Out:
# <ipython-input-37-1d65b568019a>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_hours.corr()
#              instant      year      temp     atemp  humidity  windspeed  \
# instant     1.000000  0.866014  0.136178  0.137615  0.009577  -0.074505
# year        0.866014  1.000000  0.040913  0.039222 -0.083546  -0.008740
# temp        0.136178  0.040913  1.000000  0.987672 -0.069881  -0.023125
# atemp       0.137615  0.039222  0.987672  1.000000 -0.051918  -0.062336
# humidity    0.009577 -0.083546 -0.069881 -0.051918  1.000000  -0.290105
# windspeed  -0.074505 -0.008740 -0.023125 -0.062336 -0.290105   1.000000
# casual      0.158295  0.142779  0.459616  0.454080 -0.347028   0.090287
# registered  0.282046  0.253684  0.335361  0.332559 -0.273933   0.082321
# ...

# %%
corr = df_hours.corr()
plt.figure(figsize=(15,7))
sns.heatmap(corr, annot=True, annot_kws={'size':10})
# Out:
# <ipython-input-38-ed6e5c3b9564>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df_hours.corr()
# <Axes: >

# %%
# plotting berdasarkan waktu(hour)
fig, ax = plt.subplots(figsize=(20,5))
sns.pointplot(data=df_hours, x='hour', y='count', hue='weekday', ax=ax)
ax.set(title='Plotting berdasarkan banyak peminjaman/rent berdsarakan waktu dan hari')
# Out:
# [Text(0.5, 1.0, 'Plotting berdasarkan banyak peminjaman/rent berdsarakan waktu dan hari')]

# %%
fig, ax = plt.subplots(figsize=(20,5))
sns.pointplot(data=df_hours, x='hour', y='casual', hue='weekday', ax=ax)
ax.set(title='Total Peminjaman sepede berdaskaran waktu dan user tidak teregister')
# Out:
# [Text(0.5, 1.0, 'Total Peminjaman sepede berdaskaran waktu dan user tidak teregister')]

# %%
fig, ax = plt.subplots(figsize=(20,5))
sns.pointplot(data=df_hours, x='hour', y='registered', hue='weekday', ax=ax)
ax.set(title='Total Peminjaman sepede berdaskaran waktu dan user  teregister')
# Out:
# [Text(0.5, 1.0, 'Total Peminjaman sepede berdaskaran waktu dan user  teregister')]

# %%
fig, ax = plt.subplots(figsize=(20,5))
sns.pointplot(data=df_hours, x='hour', y='count', hue='weather', ax=ax)
ax.set(title='Total Peminjaman sepeda berdasarkan Cuaca')
# Out:
# [Text(0.5, 1.0, 'Total Peminjaman sepeda berdasarkan Cuaca')]

# %%
fig, ax = plt.subplots(figsize=(20,5))
sns.barplot(data=df_hours, x='month', y='count', ax=ax)
ax.set(title='total peminjaman sepede berdasakran bulan')
# Out:
# [Text(0.5, 1.0, 'total peminjaman sepede berdasakran bulan')]

# %%
fig, ax = plt.subplots(figsize=(20,5))
sns.barplot(data=df_hours, x='weekday', y='count', ax=ax)
ax.set(title='total peminjaman sepeda berdasarkan hari kerja')
# Out:
# [Text(0.5, 1.0, 'total peminjaman sepeda berdasarkan hari kerja')]

# %%
fig, (ax1,ax2) = plt.subplots(ncols=2, figsize=(20,5))
sns.regplot(x=df_hours['temp'], y=df_hours['count'], ax=ax1 ,color='red')
ax1.set(title="hubungan antara suhu dan pengguna")
sns.regplot(x=df_hours['humidity'], y=df_hours['count'], ax=ax2)
ax2.set(title="hubungan antara kembebapan dengan pengguna")
# Out:
# [Text(0.5, 1.0, 'hubungan antara kembebapan dengan pengguna')]

# %%
fig, (ax1,ax2) = plt.subplots(ncols=2, figsize=(20,5))
sns.distplot(df_hours['count'], ax=ax1 , color ='red')
ax1.set(title='distribusi pengguna')
qqplot(df_hours['count'], ax=ax2, line='s')
ax2.set(title='Teori quantiles')
# Out:
# <ipython-input-46-1988dbf359fa>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_hours['count'], ax=ax1 , color ='red')
# [Text(0.5, 1.0, 'Teori quantiles')]

# %% [markdown]
# # Explanatory Analysis

# %% [markdown]
# 1.   Kapan waktu(bisa jam) yang sering terjadi peminjaman/rent bike sharing yang ada ?
#
# berdasarkan kecendrungan data yang ada antara dataset hours dan days diketahui bahwa berdasarkan jam rent/peminjaman banyak dilakukan pada jam 6-9 dan 16-20
#
# 2.   Berapa banyak dalam satu hari/waktu(bisa harian/bulanan/tahunan) dilakuakn peminjaman rent bike sharing?
#
# berdasarkan kecendrungan data yang ada antara dataset days didapatkan bahwa setiap hari mendapatkan jumlah yang stabil di kisanarn 4000 pengguna dan untuk dataset hours didapatkan bahwa didapatkan sekitar +-175 peminjaman sedangankan berdaskarn kedua dataset yang ada diketahui bahwa pemunjaman yang sering dilakukan berdaskaran bulan ada pada bulan 	5 - 9
#
# 3.   pengaruh cuaca(temp/atemp/hum/windspeed) terkait dengan banyaknya peminjam/rent yang terjadi
#
# berdasakran data yang ada apabila terjadi kenaikan temperaturn maka akan terjadi penuruan terkait dengan peminjaman/rent sepeda
#
# berdasarkan data yang ada apabila terjadi peningkatan kelembapan/humidity maka akan terjadi peningkatan terkait peminjaman/rent

# %% [markdown]
# # Dashboard

# %% [markdown]
# # Run streamlit app from a Google Colab Notebook
# note : pembuatan dashboard hanya menggunakan hour.csv dimana digunakan lokal tunnel untuk run streamlite

# %%
# !pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 28.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 18.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.5/189.5 kB 21.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 59.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 33.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tzlocal
#     Found existing installation: tzlocal 5.0.1
#     Uninstalling tzlocal-5.0.1:
#       Successfully uninstalled tzlocal-5.0.1
# ...

# %% [markdown]
# ## Create a streamlit app example

# %% [markdown]
# # Install localtunnel to serve the Streamlit app

# %%
import urllib
print("Password/Enpoint IP for localtunnel is:",urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
# Out:
# Password/Enpoint IP for localtunnel is: 34.125.61.32

# %%
# !npm install localtunnel
# Out:
# npm WARN saveError ENOENT: no such file or directory, open '/content/package.json'
# npm notice created a lockfile as package-lock.json. You should commit this file.
# npm WARN enoent ENOENT: no such file or directory, open '/content/package.json'
# npm WARN content No description
# npm WARN content No repository field.
# npm WARN content No README data
# npm WARN content No license field.
#
# + localtunnel@2.0.2
# added 22 packages from 22 contributors and audited 22 packages in 2.475s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# found 0 vulnerabilities

# %%
# %%writefile app.py

import pandas as pd
import plotly.express as px
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.graphics.gofplots import qqplot

import streamlit as st

st.write('# Bike Sharing Dataset')

st.markdown('''
Bike sharing systems are new generation of traditional bike rentals where whole process from membership, rental and return
back has become automatic. Through these systems, user is able to easily rent a bike from a particular position and return
back at another position. Currently, there are about over 500 bike-sharing programs around the world which is composed of
over 500 thousands bicycles. Today, there exists great interest in these systems due to their important role in traffic,
environmental and health issues.
''')



@st.cache_data
def load_data(path):
    dataset = pd.read_csv(path)
    return dataset

df_hours = load_data('hour.csv')

#
df_hours['dteday'] = pd.to_datetime(df_hours['dteday'])
df_hours = df_hours.rename(columns={'weathersit':'weather',
                       'yr':'year',
                       'mnth':'month',
                       'hr':'hour',
                       'hum':'humidity',
                       'cnt':'count'})

cols = ['season' , 'month' , 'hour' , 'holiday' , 'weekday' , 'workingday' , 'weather']
for col in cols:
    df_hours[col] = df_hours[col].astype('category')


df_hours_status_month=df_hours.groupby('month')['count'].mean()
df_hours_status_workingday=df_hours.groupby('workingday')['count'].mean()
df_hours_status_weekday=df_hours.groupby('weekday')['count'].mean()
with st.container():
    with st.container():
        col1, col2, col3 = st.columns(3)
        st.header('Bike Sharing Summary')
        with col1:
            st.header('Bike Sharing Summary Monthly')
            st.dataframe(df_hours_status_month)
        with col2:
            st.header('Bike Sharing Summary workingday')
            st.dataframe(df_hours_status_workingday)
        with col3:
            st.header('Bike Sharing Summary')
            st.dataframe(df_hours_status_weekday)
    with st.container():
        st.header('Bike Sharing Visualisation')
        option = st.selectbox(
            'Choose Graphics Summary BAR CHART?',
            ('Monthly','Weekday','Workingday')
          )

        if option == 'Monthly':
          st.bar_chart(
            df_hours,
            x = 'month',
            y = 'count',
            color = 'month'
          )
        if option == 'Weekday':
          st.bar_chart(
            df_hours,
            x = 'weekday',
            y = 'count',
            color = 'weekday'
          )
        if option == 'Workingday':
          st.bar_chart(
            df_hours,
            x = 'workingday',
            y = 'count',
            color = 'workingday'
          )
    with st.container():
        option = st.selectbox(
            'Choose Graphics Summary Line Chart',
            ('Monthly','Weekday','Workingday','Hour')
          )
        if option == 'Monthly':
          fig, ax = plt.subplots(figsize=(20,5))
          sns.pointplot(data=df_hours, x='month', y='count', hue='weekday', ax=ax)
          st.pyplot(fig)
        if option == 'Weekday':
          fig, ax = plt.subplots(figsize=(20,5))
          sns.pointplot(data=df_hours, x='weekday', y='count', hue='weekday', ax=ax)
          st.pyplot(fig)
        if option == 'Workingday':
          fig, ax = plt.subplots(figsize=(20,5))
          sns.pointplot(data=df_hours, x='workingday', y='count', hue='weekday', ax=ax)
          st.pyplot(fig)
        if option == 'Hour':
          fig, ax = plt.subplots(figsize=(20,5))
          sns.pointplot(data=df_hours, x='hour', y='count', hue='weekday', ax=ax)
          st.pyplot(fig)

    with st.container():
        st.header('Distribusi Data')
        fig, (ax1,ax2) = plt.subplots(ncols=2, figsize=(20,5))
        sns.distplot(df_hours['count'], ax=ax1 , color ='red')
        ax1.set(title='distribusi pengguna')
        qqplot(df_hours['count'], ax=ax2, line='s')
        ax2.set(title='Teori quantiles')
        st.pyplot(fig)

    with st.container():
      st.header('Pengaruh Cuaca Terhadap Sewa')
      fig, (ax1,ax2) = plt.subplots(ncols=2, figsize=(20,5))
      sns.regplot(x=df_hours['temp'], y=df_hours['count'], ax=ax1 ,color='red')
      ax1.set(title="hubungan antara suhu dan pengguna")
      sns.regplot(x=df_hours['humidity'], y=df_hours['count'], ax=ax2)
      ax2.set(title="hubungan antara kembebapan dengan pengguna")
      st.pyplot(fig)









with st.sidebar:
    st.subheader('About')
    st.markdown('This dashboard is made by Just into Data, using **Streamlit**')

st.sidebar.image('https://streamlit.io/images/brand/streamlit-mark-color.png', width=50)
# Out:
# Overwriting app.py

# %%
# 34.125.61.32
# !streamlit run app.py &>/content/logs.txt &
# !npx localtunnel --port 8501
# Out:
# npx: installed 22 in 2.366s
# your url is: https://cold-wombats-dig.loca.lt
# ^C
